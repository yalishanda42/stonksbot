# %%
import yfinance as yf

# %%
nvda = yf.Ticker("NVDA")

# %%
nvda.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2000-06-27 00:00:00-04:00    0.00000           2.0
# 2001-09-10 00:00:00-04:00    0.00000           2.0
# 2006-04-07 00:00:00-04:00    0.00000           2.0
# 2007-09-11 00:00:00-04:00    0.00000           1.5
# 2012-11-20 00:00:00-05:00    0.01875           0.0
# 2013-02-26 00:00:00-05:00    0.01875           0.0
# 2013-05-21 00:00:00-04:00    0.01875           0.0
# 2013-08-20 00:00:00-04:00    0.01875           0.0
# 2013-11-19 00:00:00-05:00    0.02125           0.0
# 2014-02-25 00:00:00-05:00    0.02125           0.0
# 2014-05-20 00:00:00-04:00    0.02125           0.0
# 2014-08-19 00:00:00-04:00    0.02125           0.0
# 2014-11-19 00:00:00-05:00    0.02125           0.0
# 2015-02-24 00:00:00-05:00    0.02125           0.0
# 2015-05-19 00:00:00-04:00    0.02450           0.0
# 2015-08-18 00:00:00-04:00    0.02450           0.0
# 2015-11-18 00:00:00-05:00    0.02875           0.0
# ...

# %%
nvda.quarterly_income_stmt
# Out:
#                                                        2024-01-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                       0.129094
# Normalized EBITDA                                   14556000000.0
# Total Unusual Items                                           0.0
# Total Unusual Items Excluding Goodwill                        0.0
# Net Income From Continuing Operation Net Minori...  12285000000.0
# Reconciled Depreciation                               387000000.0
# Reconciled Cost Of Revenue                           5312000000.0
# EBITDA                                              14556000000.0
# EBIT                                                14169000000.0
# Net Interest Income                                   231000000.0
# Interest Expense                                       63000000.0
# Interest Income                                       294000000.0
# ...

# %%
nvda.quarterly_balance_sheet
# Out:
#                                                      2024-01-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             2464000000.0
# Share Issued                                       2464000000.0
# Net Debt                                           2429000000.0
# Total Debt                                        11056000000.0
# ...                                                         ...
# Receivables                                        9999000000.0
# Accounts Receivable                                9999000000.0
# Cash Cash Equivalents And Short Term Investments  25984000000.0
# Other Short Term Investments                      18704000000.0
# Cash And Cash Equivalents                          7280000000.0
#
#                                                      2023-10-31  \
# Treasury Shares Number                                      0.0
# Ordinary Shares Number                             2466000000.0
# ...

# %%
nvda.quarterly_cash_flow
# Out:
#                                                    2024-01-31    2023-10-31  \
# Free Cash Flow                                  11245000000.0  7054000000.0
# Repurchase Of Capital Stock                     -2659000000.0 -3807000000.0
# Repayment Of Debt                                         0.0           0.0
# Issuance Of Debt                                          NaN           NaN
# Capital Expenditure                              -254000000.0  -278000000.0
# Income Tax Paid Supplemental Data                1873000000.0  4348000000.0
# End Cash Position                                7280000000.0  5519000000.0
# Beginning Cash Position                          5519000000.0  5882000000.0
# Changes In Cash                                  1761000000.0  -363000000.0
# Financing Cash Flow                             -3629000000.0 -4525000000.0
# Cash Flow From Continuing Financing Activities  -3629000000.0 -4525000000.0
# ...

# %%
nvda.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.04319
# institutionsPercentHeld          0.67495
# institutionsFloatPercentHeld     0.70541
# institutionsCount             5521.00000

# %%
nvda.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2023-06-30                 Vanguard Group Inc   0.0815  201392728
# 1    2023-06-30                     Blackrock Inc.   0.0737  182096923
# 2    2023-06-30                           FMR, LLC   0.0532  131491181
# 3    2023-06-30           State Street Corporation   0.0370   91510810
# 4    2023-06-30      Price (T.Rowe) Associates Inc   0.0222   54723581
# 5    2023-06-30      Geode Capital Management, LLC   0.0192   47459414
# 6    2023-06-30          JP Morgan Chase & Company   0.0144   35567980
# 7    2023-06-30                     Morgan Stanley   0.0135   33261283
# 8    2022-12-31  Norges Bank Investment Management   0.0108   26692722
# 9    2023-06-30         Northern Trust Corporation   0.0103   25401425
#
#          Value
# 0  85193151798
# 1  77030640367
# 2  55623399386
# 3  38710902846
# 4  23149169234
# 5  20076281310
# 6  15045966899
# 7  14070187934
# 8   3900874393
# 9  10745310803

# %%
nvda.mutualfund_holders
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2023-06-30             Vanguard Total Stock Market Index Fund   0.0297
# 1    2023-06-30                            Vanguard 500 Index Fund   0.0238
# 2    2023-05-31                            Fidelity 500 Index Fund   0.0111
# 3    2023-08-31                             SPDR S&P 500 ETF Trust   0.0110
# 4    2023-08-31                           iShares Core S&P 500 ETF   0.0094
# 5    2023-06-30                         Vanguard Growth Index Fund   0.0081
# 6    2023-08-31        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF   0.0079
# 7    2023-06-30  Vanguard Institutional Index Fund-Institutiona...   0.0068
# 8    2023-08-31                       Fidelity Growth Company Fund   0.0057
# 9    2023-05-31         Vanguard Information Technology Index Fund   0.0054
#
#      Shares        Value
# 0  73271028  30995110264
# 1  58883488  24908893093
# 2  27527635  10414805425
# 3  27236757  13442701417
# ...

# %%
nvda.insider_purchases
# Out:
#        Insider Purchases Last 6m       Shares  Trans
# 0                      Purchases     905653.0     15
# 1                          Sales     587976.0     24
# 2    Net Shares Purchased (Sold)     317677.0     39
# 3      Total Insider Shares Held  106333784.0   <NA>
# 4  % Net Shares Purchased (Sold)        0.003   <NA>
# 5                   % Buy Shares        0.009   <NA>
# 6                  % Sell Shares        0.006   <NA>

# %%
nvda.insider_transactions
# Out:
#      Shares     Value URL                                         Text  \
# 0      1667         0      Stock Award(Grant) at price 0.00 per share.
# 1     22700  19975240         Sale at price 877.00 - 882.36 per share.
# 2      7000   6215259                  Sale at price 887.89 per share.
# 3     11000   9962150                  Sale at price 905.65 per share.
# 4       128    120320                  Sale at price 940.00 per share.
# ..      ...       ...  ..                                          ...
# 145    1438         0      Stock Award(Grant) at price 0.00 per share.
# 146    1438         0      Stock Award(Grant) at price 0.00 per share.
# 147   21315         0              Stock Gift at price 0.00 per share.
# 148    1438         0      Stock Award(Grant) at price 0.00 per share.
# 149    1438         0      Stock Award(Grant) at price 0.00 per share.
#
#                    Insider         Position Transaction Start Date Ownership
# ...

# %%
nvda.insider_roster_holders
# Out:
#                     Name                 Position URL Most Recent Transaction  \
# 0           COXE TENCH C                 Director                        Sale
# 1          DABIRI JOHN O                 Director                        Sale
# 2         HUANG JEN-HSUN  Chief Executive Officer          Stock Award(Grant)
# 3       KRESS COLETTE M.  Chief Financial Officer          Stock Award(Grant)
# 4           PERRY MARK L                 Director                        Sale
# 5            PURI AJAY K                  Officer          Stock Award(Grant)
# 6  ROBERTSON DONALD F JR                  Officer          Stock Award(Grant)
# 7      SHOQUIST DEBORA C                  Officer          Stock Award(Grant)
# 8         STEVENS MARK A                 Director                        Sale
# 9        TETER TIMOTHY S          General Counsel          Stock Award(Grant)
#
#   Latest Transaction Date  Shares Owned Indirectly  Position Indirect Date  \
# ...

# %%
nvda.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          7   14    15     1           1
# 1    -1m         20   34     4     0           0
# 2    -2m         19   33     4     0           0
# 3    -3m         12   21    12     2           0

# %%
nvda.recommendations_summary
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          7   14    15     1           1
# 1    -1m         20   34     4     0           0
# 2    -2m         19   33     4     0           0
# 3    -3m         12   21    12     2           0

# %%
nvda.upgrades_downgrades
# Out:
#                                    Firm      ToGrade       FromGrade Action
# GradeDate
# 2024-05-23 17:17:04           Citigroup          Buy             Buy   main
# 2024-05-23 17:02:18       Deutsche Bank         Hold            Hold   main
# 2024-05-23 16:56:36        Craig-Hallum          Buy             Buy   main
# 2024-05-23 16:40:24             Wedbush   Outperform      Outperform   main
# 2024-05-23 15:45:18            TD Cowen          Buy             Buy   main
# ...                                 ...          ...             ...    ...
# 2012-05-14 10:19:00           Jefferies         Hold                   main
# 2012-04-05 11:07:00   Cantor Fitzgerald          Buy                   init
# 2012-02-16 12:29:00  Evercore ISI Group  Underweight                   main
# 2012-02-16 11:34:00   B of A Securities      Neutral             Buy   down
# 2012-02-13 12:27:00         FBR Capital   Outperform  Market Perform     up
#
# [757 rows x 4 columns]

# %%
nvda.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-06-26 12:00:00-04:00          5.57           NaN          NaN
# 2025-05-20 16:00:00-04:00           NaN           NaN          NaN
# 2025-02-19 16:00:00-05:00           NaN           NaN          NaN
# 2024-11-19 16:00:00-05:00           NaN           NaN          NaN
# 2024-08-21 06:00:00-04:00          5.83           NaN          NaN
# 2024-06-26 12:00:00-04:00          5.59           NaN          NaN
# 2024-06-05 15:00:00-04:00           NaN           NaN          NaN
# 2024-05-22 16:00:00-04:00          5.59          6.12       0.0954
# 2024-03-19 11:00:00-04:00          4.63          5.16       0.1145
# 2024-03-18 06:00:00-04:00          4.63          5.16       0.1145
# 2024-03-05 09:00:00-05:00          4.63          5.16       0.1145
# 2024-03-04 13:00:00-05:00          4.63          5.16       0.1145

# %%
# nvda.earnings not implemented

# %%
nvda.options
# Out:
# ('2024-05-31',
#  '2024-06-07',
#  '2024-06-14',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-05',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-10-18',
#  '2024-11-15',
#  '2024-12-20',
#  '2025-01-17',
#  '2025-02-21',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-09-19',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-06-18',
#  '2026-12-18')

# %%
opt = nvda.option_chain('2024-05-31')

# %%
opt.calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    NVDA240531C00260000 2024-05-23 19:59:29+00:00   260.0     777.99  891.50
# 1    NVDA240531C00290000 2024-05-29 17:55:27+00:00   290.0     859.74  861.50
# 2    NVDA240531C00300000 2024-05-29 13:34:35+00:00   300.0     824.95  851.20
# 3    NVDA240531C00310000 2024-05-22 19:29:14+00:00   310.0     630.87  841.85
# 4    NVDA240531C00320000 2024-05-28 13:40:27+00:00   320.0     798.29  831.10
# ..                   ...                       ...     ...        ...     ...
# 182  NVDA240531C01550000 2024-05-29 18:02:13+00:00  1550.0       0.05    0.03
# 183  NVDA240531C01600000 2024-05-29 18:10:08+00:00  1600.0       0.02    0.02
# 184  NVDA240531C01650000 2024-05-29 18:02:43+00:00  1650.0       0.01    0.01
# 185  NVDA240531C01700000 2024-05-29 18:04:20+00:00  1700.0       0.02    0.01
# 186  NVDA240531C01750000 2024-05-29 18:09:26+00:00  1750.0       0.02    0.01
#
# ...

# %%
opt.puts
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    NVDA240531P00260000 2024-05-28 13:30:24+00:00   260.0       0.01    0.00
# 1    NVDA240531P00280000 2024-05-28 13:54:06+00:00   280.0       0.01    0.00
# 2    NVDA240531P00290000 2024-05-23 13:30:16+00:00   290.0       0.01    0.00
# 3    NVDA240531P00300000 2024-05-29 13:30:06+00:00   300.0       0.01    0.00
# 4    NVDA240531P00310000 2024-05-29 14:34:36+00:00   310.0       0.01    0.00
# ..                   ...                       ...     ...        ...     ...
# 197  NVDA240531P01400000 2024-05-28 17:46:57+00:00  1400.0     255.29  243.65
# 198  NVDA240531P01450000 2024-05-17 14:08:03+00:00  1450.0     513.86  294.25
# 199  NVDA240531P01500000 2024-05-28 17:45:55+00:00  1500.0     354.10  343.40
# 200  NVDA240531P01550000 2024-05-21 13:48:17+00:00  1550.0     616.20  396.70
# 201  NVDA240531P01600000 2024-04-26 16:44:51+00:00  1600.0     727.90  530.95
#
# ...

# %%
opt.underlying
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'currency': 'USD',
#  'marketState': 'REGULAR',
#  'regularMarketChangePercent': 0.93063056,
#  'regularMarketPrice': 1149.61,
#  'exchange': 'NMS',
#  'shortName': 'NVIDIA Corporation',
#  'longName': 'NVIDIA Corporation',
#  'messageBoardId': 'finmb_32307',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 917015400000,
#  'priceHint': 2,
#  'regularMarketChange': 10.599976,
#  'regularMarketTime': 1717007167,
#  'regularMarketDayHigh': 1154.92,
#  'regularMarketDayRange': '1109.0201 - 1154.92',
#  'regularMarketDayLow': 1109.0201,
#  'regularMarketVolume': 42789422,
# ...

# %%
nvda.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2023-04-10 00:00:00-04:00    2470000128
# 2023-05-04 00:00:00-04:00    2506249984
# 2023-05-05 00:00:00-04:00    2470000128
# 2023-05-10 00:00:00-04:00    2473129984
# 2023-05-13 00:00:00-04:00    2520689920
#                                 ...
# 2024-04-25 00:00:00-04:00    2586160128
# 2024-04-25 00:00:00-04:00    2500000000
# 2024-05-16 00:00:00-04:00    2459830016
# 2024-05-23 00:00:00-04:00    2459830016
# 2024-05-23 00:00:00-04:00    2471130112
# Length: 64, dtype: int64
