# %%
# !pip install yfinance==0.2.40

# %%
import yfinance as yf

# %%
nvda = yf.Ticker("NVDA")
nvda.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
nvda_news = nvda.news
nvda_news
# Out:
# [{'uuid': '67ed1cfd-7d67-30f9-91b8-defb89bcd595',
#   'title': 'These Stocks Are Moving the Most Today: American Airlines, Marathon Oil, Chewy, Dick’s, AST SpaceMobile, Abercrombie, and More',
#   'publisher': 'Barrons.com',
#   'link': 'https://finance.yahoo.com/m/67ed1cfd-7d67-30f9-91b8-defb89bcd595/these-stocks-are-moving-the.html',
#   'providerPublishTime': 1717003200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/CGA0Uv4Bt1IfZSrvD_KWjA--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/2112019a858d768c56365c8883288c38',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/RPpqq009fJwyA3N2Wh_Waw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/2112019a858d768c56365c8883288c38',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
# ...

# %%
len(nvda_news)
# Out:
# 8

# %%
links = [article["link"] for article in nvda_news]
links
# Out:
# ['https://finance.yahoo.com/m/67ed1cfd-7d67-30f9-91b8-defb89bcd595/these-stocks-are-moving-the.html',
#  'https://finance.yahoo.com/m/0f9565bc-0e24-308e-9eae-0b9d8893bd1c/at-least-the-mag-7-is-turning.html',
#  'https://finance.yahoo.com/m/bed64c45-bcf1-320e-8059-2a6c5bfeca1b/nvidia-%28nvda%29-q1-2025.html',
#  'https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks%3A.html',
#  'https://finance.yahoo.com/news/nvidia-rush-overtake-apple-etfs-153700293.html',
#  'https://finance.yahoo.com/m/64d6a797-a922-3c83-82d1-5e18ab403870/nvidia-stock-gains-as-it.html',
#  'https://finance.yahoo.com/m/dc591aa5-8656-399f-a2b0-90fb4c8c329e/nvidia-holds-near-all-time.html',
#  'https://finance.yahoo.com/news/5-top-ranked-stocks-powering-152100499.html']
